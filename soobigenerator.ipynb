# %%
# %pip install lyricsgenius
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: C:\Users\ahmad\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %%
import lyricsgenius
import re
import os
import random

random.seed(1)

# ——— CONFIG ———
ACCESS_TOKEN = "BApPxRnaYSaesie1lGfckMJPCPYUPkoNd4lQseefRNam_ry3wS7J3WfdCqEsOqUp"
ARTISTS = [

    "Frank Ocean",
    "Tyler, the Creator",
    "The Weeknd",
    "Jeremy Zucker",
    "Sufjan Stevens",
    "Phoebe Bridgers",
    "Lana Del Rey",
    "Billie Eilish",
    "Clairo",
    "Rex Orange County",
    "Dominic Fike",
    "Tame Impala",
    "Biffy Clyro",
    "ATO",
    "The 1975",
    "The Neighbourhood",
    "Ciggaretes After Sex",
    "Sombr",
    "Hozier",
    "Joji",
    "Girl in Red",
    "Lorde",
    
]
OUTPUT_DIR            = "lyrics_output"            
COMBINED_FILENAME     = os.path.join(OUTPUT_DIR, "all_artists_lyrics.txt")
MAX_SONGS_PER_ARTIST  = 100                 
# ————————————————————

genius = lyricsgenius.Genius(ACCESS_TOKEN)
genius.remove_section_headers = True

def clean_lyrics(raw):
    text = re.sub(r'\[.*?\]', '', raw)
    lines = text.splitlines()
    return "\n".join(
        ln.strip() for ln in lines
        if ln.strip() 
           and not re.search(r'Contributors|Lyrics|Read More', ln, re.IGNORECASE)
    )

def get_artist_lyrics(artist_name):
    artist = genius.search_artist(artist_name, max_songs=MAX_SONGS_PER_ARTIST, sort="popularity")
    cleaned = []
    songs = artist.songs[:]
    random.shuffle(songs)
    for song in songs:
        try:
            cleaned.append(clean_lyrics(song.lyrics))
        except Exception as e:
            print(f"⚠️ {artist_name}: couldn’t fetch “{song.title}”: {e}")
    return cleaned

def save_per_artist(artist_name, lyrics_list):
    safe = artist_name.replace(",", "").replace(" ", "_")
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    path = os.path.join(OUTPUT_DIR, f"{safe}.txt")
    with open(path, "w", encoding="utf-8") as f:
        for block in lyrics_list:
            f.write(block.strip() + "\n\n")
    print(f"✅ Saved {len(lyrics_list)} songs → {path}")

def append_to_combined(lyrics_list):
    # make sure the combined file exists (and clear it at start)
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    # we clear it once before the loop, so this function only appends
    with open(COMBINED_FILENAME, "a", encoding="utf-8") as f:
        for block in lyrics_list:
            f.write(block.strip() + "\n\n")

if __name__ == "__main__":
    # clear combined file at the very start
    os.makedirs(OUTPUT_DIR, exist_ok=True)
    open(COMBINED_FILENAME, "w", encoding="utf-8").close()

    for artist in dict.fromkeys(ARTISTS):
        print(f"\n🚀 Fetching: {artist}")
        lyrics = get_artist_lyrics(artist)
        if lyrics:
            save_per_artist(artist, lyrics)
            append_to_combined(lyrics)
        else:
            print(f"❌ No lyrics for: {artist}")

    print(f"\n🎉 All done! Combined file at: {COMBINED_FILENAME}")
# Out:
# 🚀 Fetching: Jeff Buckley
# Searching for songs by Jeff Buckley...
#
# Song 1: "Hallelujah"
# Song 2: "Lover, You Should’ve Come Over"
# Song 3: "Grace"
# Song 4: "Last Goodbye"
# Song 5: "Mojo Pin"
# Song 6: "Forget Her"
# Song 7: "Lilac Wine"
# Song 8: "So Real"
# Song 9: "Everybody Here Wants You"
# Song 10: "Dream Brother"
# Song 11: "Corpus Christi Carol"
# Song 12: "Eternal Life"
# Song 13: "All Flowers In Time Bend Towards The Sun"
# Song 14: "I Know It’s Over"
# Song 15: "Mama, You Been on My Mind (Studio Outtake - 1993)"
# Song 16: "You & I"
# Song 17: "Nightmares by the Sea"
# Song 18: "Morning Theft"
# Song 19: "New Year’s Eve Prayer"
# Song 20: "Vancouver"
# Song 21: "The Sky Is a Landfill"
# Song 22: "Opened Once"
# Song 23: "Satisfied Mind"
# Song 24: "Je N’en Connais Pas La Fin (Live At Sin-é)"
# Song 25: "Witches’ Rave"
# Song 26: "Yard of Blonde Girls"
# Song 27: "I Want Someone Badly"
# Song 28: "Calling You"
# ...
